# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Delowar/LLM-Email-Subjector/blob/main/process_email_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.cuda.is_available())
print(torch.__version__)
# Out:
# True
# 2.5.1+cu124

# %%
# !pip install datasets -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.8 MB/s eta 0:00:00

# %%
# dependencies
import pandas as pd
import random
from datasets import load_dataset, Dataset
import os

# %% [markdown]
# ## Load the Dataset
# Enron email parsed Dataset from Huggingface: [Hellisotherpeople/enron_emails_parsed](https://huggingface.co/datasets/Hellisotherpeople/enron_emails_parsed)

# %%
dataset = load_dataset("Hellisotherpeople/enron_emails_parsed", split="train")
dataset
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# emails_parsed.parquet:   0%|          | 0.00/676M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/535703 [00:00<?, ? examples/s]
# Dataset({
#     features: ['date', 'from', 'to', 'subject', 'body'],
#     num_rows: 535703
# })

# %% [markdown]
# ## Process the dataset

# %%
df = dataset.to_pandas()

# %%
df.head(5)
# Out:
#                                     date                     from  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)  phillip.allen@enron.com
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)  phillip.allen@enron.com
#
#                         to    subject  \
# 0     tim.belden@enron.com
# 1  john.lavorato@enron.com        Re:
# 2   leah.arsdall@enron.com   Re: test
# 3    randall.gay@enron.com
# 4     greg.piper@enron.com  Re: Hello
#
#                                                 body
# 0                              Here is our forecast
# 1   Traveling to have a business meeting takes th...
# 2                     test successful.  way to go!!!
# 3   Randy, Can you send me a schedule of the sala...
# 4                  Let's shoot for Tuesday at 11:45.

# %%
# Keep only subject and body columns
df = df[["subject", "body"]]

# %%
# Clean subject: remove prefixes like "Re:", "FW:".
df["subject"] = df["subject"].str.replace(r'^\s*(Re:|FW:|Fw:)\s*', '', case=False, regex=True)

# Clean body: remove forwarded sections
df["body"] = df["body"].str.split("---------------------- Forwarded by").str[0].str.strip()

# Remove patterns like "Cc:" or closings like "Regards"
pattern = r'^(Cc:|Bcc:).*@|(Regards|Best),?\s+\w+'
df = df[~df["body"].str.contains(pattern, regex=True, case=False)].reset_index(drop=True)
# Out:
# <ipython-input-8-715542351ba2>:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df[~df["body"].str.contains(pattern, regex=True, case=False)].reset_index(drop=True)

# %%
df.head(10)
# Out:
#                                              subject  \
# 0
# 1
# 2                                               test
# 3
# 4                                              Hello
# 5                                              Hello
# 6
# 7                           PRC review - phone calls
# 8                         High Speed Internet Access
# 9  fixed forward or other Collar floor gas price ...
#
#                                                 body
# 0                               Here is our forecast
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy, Can you send me a schedule of the salar...
# 4                  Let's shoot for Tuesday at 11:45.
# 5  Greg, How about either next Tuesday or Thursda...
# 6  Please cc the following distribution list with...
# 7                   any morning between 10 and 11:30
# 8  1. login:  pallen pw: ke9davis I don't think t...
# 9

# %%
df = df.dropna()  # Drop NaN values
# removing whitespaces or empty string
df = df[
    df["subject"].str.strip().astype(bool) &
    df["body"].str.strip().astype(bool)
]

# %%
df.shape
# Out:
# (325920, 2)

# %%
# Apply length filters
df["sub_len_char"] = df["subject"].str.len()
df["body_len_char"] = df["body"].str.len()


df.head(10)
# Out:
#                                               subject  \
# 2                                                test
# 4                                               Hello
# 5                                               Hello
# 7                            PRC review - phone calls
# 8                          High Speed Internet Access
# 10  FW: fixed forward or other Collar floor gas pr...
# 15                                   2001 Margin Plan
# 21                             Not business related..
# 22                        Original Sept check/closing
# 24                                     San Juan Index
#
#                                                  body  sub_len_char  \
# 2                      test successful.  way to go!!!             4
# 4                   Let's shoot for Tuesday at 11:45.             5
# 5   Greg, How about either next Tuesday or Thursda...             5
# 7                    any morning between 10 and 11:30            24
# 8   1. login:  pallen pw: ke9davis I don't think t...            26
# 10  Mr. Buckner, For delivered gas behind San Dieg...            55
# 15                  Paula, 35 million is fine Phillip            16
# 21  I think Fletch has a good CPA.  I am still doi...            22
# 22  Brenda, Please use the second check as my Octo...            27
# 24  Liane, As we discussed yesterday, I am concern...            14
#
#     body_len_char
# 2              30
# 4              33
# 5              56
# 7              32
# 8             202
# 10            205
# 15             33
# 21             56
# 22            140
# 24           2130

# %%
import numpy as np
np.min(df["sub_len_char"]), np.max(df["sub_len_char"])
# Out:
# (1, 2009607)

# %%
np.min(df["body_len_char"]), np.max(df["body_len_char"])
# Out:
# (1, 2010630)

# %%
# For taking best emails, keep rows where subject length in between 20 to 80 characters
# and body length in between 50 to 1500

df = df[(df["sub_len_char"] >= 20) & (df["sub_len_char"] <= 80)]
df = df[(df["body_len_char"] >= 50) & (df["body_len_char"] <= 1500)]
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (100923, 4)

# %%
df.tail()
# Out:
#                                                 subject  \
# 100918          EcoElectrica LNG Cargo in January 2002
# 100919  Reminder: Risk Management Simulation Questions
# 100920                            Non-Exempt Scorecard
# 100921                          Weekly Reports are Due
# 100922                           Latest Marketing List
#
#                                                      body  sub_len_char  \
# 100918  Based on today's closing NYMEX prices there is...            39
# 100919  Hi Andy,  Thank you for briefly meeting with m...            47
# 100920  The following was developed in an effort to as...            21
# 100921  REMINDER:  Your weekly update for Philippe and...            23
# 100922  Please find attached the latest, and what shou...            22
#
#         body_len_char
# 100918            875
# 100919            538
# 100920            162
# 100921            146
# 100922           1093

# %%
# Create subset with randomly 15000 rows taking body & subject columns
df_subset = df[["body", "subject"]].sample(n=15_000, random_state=42).reset_index(drop=True)

# %%
df_subset.shape
# Out:
# (15000, 2)

# %% [markdown]
# # Including possible prompt instructions

# %%
# Define possible prompt instructions
instructions = [
    "Create a concise subject line for this email:",
    "Generate an email subject for this content:",
    "What would be a good subject for this message?",
    "Summarize this email into a subject line:",
    "Write a professional subject for:",
    "The following is the body of an email. Write a good subject for it:",
    "What would be an appropriate subject for this content?",
    "Suggest a subject line for the email below:",
]

# %%
# Function for adding prompt instructions with the body
def format_instruction(body):
    instruction = random.choice(instructions)
    return f"{instruction}\n\n{body}"

# %%
email_subjects = pd.DataFrame()

# %%
# Apply prompt formatting
email_subjects["input"] = df_subset["body"].apply(format_instruction)
email_subjects["output"] = df_subset["subject"]

# %%
email_subjects.head(10)
# Out:
#                                                input  \
# 0  Summarize this email into a subject line:\n\nK...
# 1  The following is the body of an email. Write a...
# 2  Write a professional subject for:\n\nThe infor...
# 3  What would be an appropriate subject for this ...
# 4  What would be a good subject for this message?...
# 5  What would be a good subject for this message?...
# 6  What would be an appropriate subject for this ...
# 7  Suggest a subject line for the email below:\n\...
# 8  What would be a good subject for this message?...
# 9  What would be an appropriate subject for this ...
#
#                                               output
# 0                         EES Daily for October 16th
# 1  Purchase and Sale Nominations - Eastrans Pipel...
# 2                   revised daily energy letter 1/22
# 3             Video Message from Ken Lay on Up Front
# 4                          Team Development Training
# 5                              FANTASY FOOTBALL 2000
# 6  Request Submitted: Access Request for patti.su...
# 7                Weekly Activity Report-Roswell Area
# 8                        Flight back from Super Bowl
# 9                               ICE physical volumes

# %% [markdown]
# ## Spliting into train, valid and test data

# %%
from sklearn.model_selection import train_test_split

# %%
# Split into train/validation/test as (70/15/15)
train_df, temp_df = train_test_split(email_subjects, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(email_subjects, test_size=0.5, random_state=42)

# %%
# Shapes
print(f"Train shape: {train_df.shape}")
print(f"Validation shape: {val_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (10500, 2)
# Validation shape: (7500, 2)
# Test shape: (7500, 2)

# %% [markdown]
# # Saving final data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define directories
save_path = "/content/drive/MyDrive/Colab Notebooks/email_subject/processed_data"

# Create the directory if it doesn't exist
os.makedirs(save_path, exist_ok=True)

# %%
# Save the dataframes to CSV files in Google Drive

train_df.to_csv(os.path.join(save_path, 'email_subject_train.csv'), index=False)
val_df.to_csv(os.path.join(save_path, 'email_subject_val.csv'), index=False)
test_df.to_csv(os.path.join(save_path, 'emai_subject_test.csv'), index=False)

# %% [markdown]
# ## Final data sample

# %%
# Sample of final data
print(f"Input (body): {email_subjects['input'][0]}")
print(f"\nOutput (Subject): {email_subjects['output'][0]}")
# Out:
# Input (body): Summarize this email into a subject line:
#
# Kysa M. Alport Enron North America (O) 503-464-7486 (C) 503-706-5308
#
# Output (Subject): EES Daily for October 16th

# %%
print(f"Input (body): {email_subjects['input'][1100]}")
print(f"\nOutput (Subject): {email_subjects['output'][1100]}")
# Out:
# Input (body): Summarize this email into a subject line:
#
# Coast This just came to me today.  This information is widely available to corporations and law enforcement around the country.  It will likely hit the media in the next day or so.  This is all the information that is available. Enron Corp. Business Controls/Corporate Security received the following information via the National Threat Warning system.  While we do not wish to unduly alarm employees, the specificity of the information dictated immediate dissemination to our West Coast offices. THE FBI IS IN POSSESSION OF UNCORROBORATED INFORMATION INDICATING THE POSSIBILITY OF ADDITIONAL TERRORIST ATTACKS AGAINST THE UNITED STATES, SPECIFICALLY THE WEST COAST.  REPORTEDLY, UNSPECIFIED GROUPS ARE TARGETING SUSPENSION BRIDGES ON THE WEST COAST.  SIX INCIDENTS ARE TO TAKE PLACE DURING RUSH HOUR BEGINNING FRIDAY, NOVEMBER 2 AND CONTINUING THROUGH NOVEMBER 7, 2001. NO FURTHER INFORMATION ABOUT THIS ALLEGED ATTACK IS KNOWN AT THIS TIME. THE FBI IS ATTEMPTING TO VERIFY THE VALIDITY OF THIS REPORT.  RECIPIENTS WILL BE UPDATED AS EVENTS WARRANT. RECIPIENTS WHO RECEIVE OR DEVELOP INFORMATION RELATED TO THIS MATTER SHOULD IMMEDIATELY CONTACT THEIR LOCAL FBI OFFICE. We will keep you apprised if we receive any further information. Thank you.
#
# Output (Subject): FBI information regarding possible terrorist threat on West
